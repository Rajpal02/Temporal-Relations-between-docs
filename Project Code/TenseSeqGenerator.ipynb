# %%
from nltk_verb_tense import get_verb_tenses
import data_parse
import string
import json

# %% [markdown]
# ### File Parsing

# %%
news = data_parse.parse_files('data')
# Out:
# Parsing file: weather_news.txt
# Parsed weather_news to: data/weather_news.json
# Parsing file: technology_news1.txt
# Parsed technology_news1 to: data/technology_news1.json
# Parsing file: politics1.txt
# Parsed politics1 to: data/politics1.json
# Parsing file: business_news.txt
# Parsed business_news to: data/business_news.json
# Parsing file: technology_news.txt
# Parsed technology_news to: data/technology_news.json
# Parsing file: politics.txt
# Parsed politics to: data/politics.json
# Parsing file: sports_news.txt
# Parsed sports_news to: data/sports_news.json
# Parsing file: sports_news1.txt
# Parsed sports_news1 to: data/sports_news1.json
# Parsing file: crime_news.txt
# Parsed crime_news to: data/crime_news.json

# %%
print(news.keys())
# Out:
# dict_keys(['weather_news', 'technology_news1', 'politics1', 'business_news', 'technology_news', 'politics', 'sports_news', 'sports_news1', 'crime_news'])

# %% [markdown]
# Append similar categories together

# %%
appended_news = {}
for each_news in news:
    category_news = each_news.rstrip(string.digits)
    if category_news in appended_news:
        appended_news[category_news] += news[each_news]
    else:
        appended_news[category_news] = news[each_news]
print(appended_news.keys())
# Out:
# dict_keys(['weather_news', 'technology_news', 'politics', 'business_news', 'sports_news', 'crime_news'])

# %% [markdown]
# ### Analyse Verb Tenses

# %%
text1 = "The initial moisture will likely start as rain, and some thunderstorms could develop with heavy rain and small hail overnight, according to the National Weather Service in Boulder. But it will change over to a wintry mix and then to snow over the plains as we move into early Saturday morning. A series of storm systems will bring colder temps & snow beginning Friday night & continuing through the weekend. Precipitation articleegins as rain Friday & early Saturday for lower elevations. Roads are expected to become slick at times, especially in the mountains. #cowx pic.twitter.com/fRJlcOuWDs"

x, y = get_verb_tenses(text1)
print(x)
# Out:
# {'sequence': ['future', 'future', 'present', 'future', 'present', 'future', 'present', 'present', 'present', 'past'], 'tenses': {'future': 4, 'present': 5, 'past': 1}, 'words': [(3, 'will', 'future'), (12, 'could', 'future'), (22, 'according', 'present'), (33, 'will', 'future'), (49, 'move', 'present'), (60, 'will', 'future'), (70, 'continuing', 'present'), (76, 'articleegins', 'present'), (88, 'are', 'present'), (89, 'expected', 'past')]}

# %%
tense_tags = []
for i in y:
    if (i[1] not in tense_tags):
        tense_tags.append(i[1])
print(tense_tags)
# Out:
# ['DT', 'JJ', 'NN', 'MD', 'RB', 'VB', 'IN', ',', 'CC', 'NNS', 'VBG', 'TO', 'NNP', '.', 'PRP', 'VBP', 'VBZ', 'JJR', 'VBN', '#']

# %%
for index, i in enumerate(y):
    if i[1] == "VBP":
        print(index, i)
# Out:
# 49 ('move', 'VBP')
# 88 ('are', 'VBP')

# %% [markdown]
# ### Bigram Tense Sequence Finder

# %%
def get_bigram_seq(article):
    if (type(article) == str):
        article = [article]
    map = {}
    total_tense_count = 0
    tense_list = []
    for sentence in article:
        tense, _ = get_verb_tenses(sentence)
        tense_seq = tense['sequence'] 
        if (tense_seq and len(tense_seq) > 1):
            tense_list.append(tense)
            for i in range(len(tense_seq) - 1):
                current = tense_seq[i] + " " + tense_seq[i+1]
                if current in map:
                    map[current] += 1
                else:
                    map[current] = 1
                total_tense_count += 1
                # if tense_seq[i] in map:
                #     map[tense_seq[i]] += 1
                # else:
                #     map[tense_seq[i]] = 1
            # if tense_seq[-1] in map:
            #     map[tense_seq[-1]] += 1
            # else:
            #     map[tense_seq[-1]] = 1
    for seq in map:
        map[seq] = map[seq] / total_tense_count
    return map, tense_list

# %% [markdown]
# #### Testing

# %%
x, y = get_bigram_seq(["The initial moisture will likely start as rain, and some thunderstorms could develop with heavy rain and small hail overnight, according to the National Weather Service in Boulder. ", "But it will change over to a wintry mix and then to snow over the plains as we move into early Saturday morning. A series of storm systems will bring colder temps & snow beginning Friday night & continuing through the weekend. Precipitation begins as rain Friday & early Saturday for lower elevations. Roads are expected to become slick at times, especially in the mountains. #cowx pic.twitter.com/fRJlcOuWDs"])

# %%
x
# Out:
# {'future future': 0.125,
#  'future present': 0.375,
#  'present future': 0.125,
#  'present present': 0.25,
#  'present past': 0.125}

# %%
y
# Out:
# [{'sequence': ['future', 'future', 'present'],
#   'tenses': {'future': 2, 'present': 1},
#   'words': [(3, 'will', 'future'),
#    (12, 'could', 'future'),
#    (22, 'according', 'present')]},
#  {'sequence': ['future',
#    'present',
#    'future',
#    'present',
#    'present',
#    'present',
#    'past'],
#   'tenses': {'future': 2, 'present': 4, 'past': 1},
#   'words': [(2, 'will', 'future'),
#    (18, 'move', 'present'),
#    (29, 'will', 'future'),
#    (39, 'continuing', 'present'),
#    (45, 'begins', 'present'),
#    (57, 'are', 'present'),
#    (58, 'expected', 'past')]}]

# %%
def getArticleText(article_category, article_id):
    for category in appended_news:
        if category == article_category:
            for article in appended_news[category]:
                if article["id"] == article_id:
                    return article['text']
    return None

# %%
text = getArticleText("weather_news", "weather_news-2")

# %% [markdown]
# ### Finding Bigram Tense sequence for news

# %%
news_tense = {}
for category in appended_news:
    news_tense[category] = []
    for article in appended_news[category]:
        print(f"\rAnalyzing: {category} ({article['id']})     ", end='')
        article_tense = {}
        article_tense["id"] = article["id"] 
        article_tense["sentence_tense_seq"], _ = get_bigram_seq(article['text'])
        article_tense["full_tense_seq"], _ = get_bigram_seq(" ".join(article['text']))
        news_tense[category].append(article_tense)
    print(f"\rAnalyzed: {category}                                     ")
# Out:
# Analyzed: weather_news
# Analyzed: technology_news
# Analyzed: politics
# Analyzed: business_news
# Analyzed: sports_news
# Analyzed: crime_news

# %%
news_tense
# Out:
# {'weather_news': [{'id': 'weather_news-0',
#    'sentence_tense_seq': {'present present': 1.0},
#    'full_tense_seq': {'present present': 1.0}},
#   {'id': 'weather_news-1',
#    'sentence_tense_seq': {'present past': 0.25,
#     'past past': 0.375,
#     'past present': 0.21875,
#     'present present': 0.0625,
#     'future present': 0.03125,
#     'past future': 0.03125,
#     'future past': 0.03125},
#    'full_tense_seq': {'present past': 0.24489795918367346,
#     'past past': 0.3673469387755102,
#     'past present': 0.22448979591836735,
#     'present present': 0.08163265306122448,
#     'present future': 0.02040816326530612,
#     'future present': 0.02040816326530612,
#     'past future': 0.02040816326530612,
#     'future past': 0.02040816326530612}},
#   {'id': 'weather_news-2',
#    'sentence_tense_seq': {'present future': 0.5, 'future present': 0.5},
#    'full_tense_seq': {'present present': 0.6923076923076923,
#     'present past': 0.07692307692307693,
#     'past present': 0.07692307692307693,
#     'present future': 0.07692307692307693,
#     'future present': 0.07692307692307693}},
#   {'id': 'weather_news-3',
#    'sentence_tense_seq': {'present past': 0.10810810810810811,
#     'past present': 0.08108108108108109,
#     'present present': 0.5945945945945946,
#     'present future': 0.13513513513513514,
#     'future present': 0.08108108108108109},
#    'full_tense_seq': {'present present': 0.5454545454545454,
#     'present past': 0.09090909090909091,
#     'past present': 0.06493506493506493,
#     'present future': 0.12987012987012986,
#     'future present': 0.14285714285714285,
#     'past future': 0.025974025974025976}},
#   {'id': 'weather_news-4',
#    'sentence_tense_seq': {'present present': 0.46153846153846156,
#     'present past': 0.11538461538461539,
#     'future present': 0.34615384615384615,
#     'future future': 0.07692307692307693},
#    'full_tense_seq': {'present present': 0.3,
#     'present past': 0.06,
#     'past present': 0.04,
#     'present future': 0.24,
#     'future present': 0.26,
#     'future future': 0.08,
#     'past future': 0.02}},
#   {'id': 'weather_news-5',
#    'sentence_tense_seq': {'present present': 0.5584415584415584,
#     'present future': 0.06493506493506493,
#     'present past': 0.18181818181818182,
#     'future present': 0.05194805194805195,
#     'past present': 0.07792207792207792,
#     'future past': 0.012987012987012988,
#     'future future': 0.012987012987012988,
#     'past past': 0.025974025974025976,
#     'past future': 0.012987012987012988},
#    'full_tense_seq': {'present present': 0.5245901639344263,
#     'present future': 0.06557377049180328,
#     'future present': 0.07377049180327869,
#     'present past': 0.14754098360655737,
#     'past present': 0.13114754098360656,
#     'future past': 0.00819672131147541,
#     'past future': 0.01639344262295082,
#     'future future': 0.01639344262295082,
#     'past past': 0.01639344262295082}},
#   {'id': 'weather_news-6',
#    'sentence_tense_seq': {'past past': 0.14705882352941177,
#     'past present': 0.17647058823529413,
#     'present past': 0.17647058823529413,
#     'present present': 0.29411764705882354,
#     'past future': 0.08823529411764706,
#     'present future': 0.058823529411764705,
#     'future present': 0.058823529411764705},
#    'full_tense_seq': {'past present': 0.17543859649122806,
#     'present present': 0.3157894736842105,
#     'present past': 0.17543859649122806,
#     'past past': 0.12280701754385964,
#     'present future': 0.05263157894736842,
#     'future past': 0.05263157894736842,
#     'past future': 0.05263157894736842,
#     'future present': 0.05263157894736842}},
#   {'id': 'weather_news-7',
#    'sentence_tense_seq': {'present past': 0.3333333333333333,
#     'past present': 0.3333333333333333,
#     'present present': 0.3333333333333333},
#    'full_tense_seq': {'present past': 0.041666666666666664,
#     'past present': 0.041666666666666664,
#     'present present': 0.08333333333333333,
#     'present future': 0.0625,
#     'future future': 0.7291666666666666,
#     'future present': 0.041666666666666664}},
#   {'id': 'weather_news-8',
#    'sentence_tense_seq': {},
#    'full_tense_seq': {'present past': 0.125,
#     'past present': 0.125,
#     'present future': 0.25,
#     'future present': 0.125,
#     'present present': 0.375}},
#   {'id': 'weather_news-9',
#    'sentence_tense_seq': {'present present': 0.5333333333333333,
#     'present future': 0.06666666666666667,
#     'future past': 0.06666666666666667,
#     'future present': 0.06666666666666667,
#     'present past': 0.26666666666666666},
#    'full_tense_seq': {'past past': 0.02631578947368421,
#     'past present': 0.13157894736842105,
#     'present present': 0.5789473684210527,
#     'present future': 0.05263157894736842,
#     'future past': 0.02631578947368421,
#     'past future': 0.02631578947368421,
#     'future present': 0.05263157894736842,
#     'present past': 0.10526315789473684}},
#   {'id': 'weather_news-10',
#    'sentence_tense_seq': {'past future': 0.11764705882352941,
#     'future past': 0.11764705882352941,
#     'past present': 0.11764705882352941,
#     'present past': 0.11764705882352941,
#     'future future': 0.029411764705882353,
#     'future present': 0.14705882352941177,
#     'present present': 0.2647058823529412,
#     'present future': 0.08823529411764706},
#    'full_tense_seq': {'past future': 0.09090909090909091,
#     'future past': 0.10909090909090909,
#     'past present': 0.12727272727272726,
#     'present future': 0.10909090909090909,
#     'present present': 0.3090909090909091,
#     'present past': 0.09090909090909091,
#     'future future': 0.07272727272727272,
#     'future present': 0.09090909090909091}},
#   {'id': 'weather_news-11',
#    'sentence_tense_seq': {'past future': 0.07692307692307693,
#     'future past': 0.23076923076923078,
#     'past present': 0.07692307692307693,
#     'present present': 0.19230769230769232,
#     'future present': 0.23076923076923078,
#     'past past': 0.07692307692307693,
#     'present past': 0.038461538461538464,
#     'present future': 0.07692307692307693},
#    'full_tense_seq': {'past future': 0.08771929824561403,
#     'future past': 0.10526315789473684,
#     'past present': 0.08771929824561403,
#     'present future': 0.21052631578947367,
#     'present past': 0.05263157894736842,
#     'future future': 0.07017543859649122,
#     'future present': 0.19298245614035087,
#     'present present': 0.14035087719298245,
#     'past past': 0.05263157894736842}},
#   {'id': 'weather_news-12',
#    'sentence_tense_seq': {'present past': 0.4,
#     'past future': 0.26666666666666666,
#     'future future': 0.13333333333333333,
#     'future present': 0.13333333333333333,
#     'past present': 0.06666666666666667},
#    'full_tense_seq': {'present past': 0.2727272727272727,
#     'past future': 0.18181818181818182,
#     'future future': 0.2727272727272727,
#     'future present': 0.13636363636363635,
#     'present present': 0.045454545454545456,
#     'past present': 0.09090909090909091}},
#   {'id': 'weather_news-13',
#    'sentence_tense_seq': {'future future': 0.5714285714285714,
#     'future past': 0.14285714285714285,
#     'past past': 0.14285714285714285,
#     'future present': 0.14285714285714285},
#    'full_tense_seq': {'future future': 0.5625,
#     'future past': 0.125,
#     'past future': 0.0625,
#     'future present': 0.0625,
#     'present future': 0.0625,
#     'past past': 0.0625,
#     'past present': 0.0625}},
#   {'id': 'weather_news-14',
#    'sentence_tense_seq': {'future future': 0.5714285714285714,
#     'future past': 0.14285714285714285,
#     'past past': 0.14285714285714285,
#     'future present': 0.14285714285714285},
#    'full_tense_seq': {'future future': 0.5625,
#     'future past': 0.125,
#     'past future': 0.0625,
#     'future present': 0.0625,
#     'present future': 0.0625,
#     'past past': 0.0625,
#     'past present': 0.0625}},
#   {'id': 'weather_news-15',
#    'sentence_tense_seq': {'future present': 0.5, 'present present': 0.5},
#    'full_tense_seq': {'past future': 0.07692307692307693,
#     'future present': 0.15384615384615385,
#     'present future': 0.15384615384615385,
#     'future future': 0.38461538461538464,
#     'present present': 0.07692307692307693,
#     'future past': 0.07692307692307693,
#     'past past': 0.07692307692307693}},
#   {'id': 'weather_news-16',
#    'sentence_tense_seq': {'future future': 0.6,
#     'present present': 0.2,
#     'present future': 0.2},
#    'full_tense_seq': {'past future': 0.0625,
#     'future future': 0.5,
#     'future present': 0.125,
#     'present future': 0.125,
#     'present present': 0.0625,
#     'future past': 0.0625,
#     'past present': 0.0625}},
#   {'id': 'weather_news-17',
#    'sentence_tense_seq': {'future past': 0.14285714285714285,
#     'past present': 0.14285714285714285,
#     'future future': 0.2857142857142857,
#     'future present': 0.2857142857142857,
#     'present future': 0.14285714285714285},
#    'full_tense_seq': {'past future': 0.058823529411764705,
#     'future future': 0.35294117647058826,
#     'future past': 0.11764705882352941,
#     'past present': 0.058823529411764705,
#     'present future': 0.17647058823529413,
#     'future present': 0.11764705882352941,
#     'past past': 0.11764705882352941}},
#   {'id': 'weather_news-18',
#    'sentence_tense_seq': {'future future': 0.5714285714285714,
#     'future past': 0.14285714285714285,
#     'past past': 0.14285714285714285,
#     'present past': 0.14285714285714285},
#    'full_tense_seq': {'future future': 0.5,
#     'future past': 0.0625,
#     'past future': 0.0625,
#     'future present': 0.125,
#     'present future': 0.0625,
#     'present past': 0.0625,
#     'past past': 0.125}},
#   {'id': 'weather_news-19',
#    'sentence_tense_seq': {'past present': 0.04,
#     'past future': 0.04,
#     'future future': 0.12,
#     'future present': 0.08,
#     'present present': 0.52,
#     'present future': 0.08,
#     'present past': 0.08,
#     'past past': 0.04},
#    'full_tense_seq': {'future past': 0.047619047619047616,
#     'past present': 0.047619047619047616,
#     'present past': 0.07142857142857142,
#     'past future': 0.047619047619047616,
#     'future future': 0.11904761904761904,
#     'future present': 0.09523809523809523,
#     'present present': 0.47619047619047616,
#     'present future': 0.07142857142857142,
#     'past past': 0.023809523809523808}},
#   {'id': 'weather_news-20',
#    'sentence_tense_seq': {'present present': 0.4,
#     'past present': 0.1,
#     'present past': 0.2,
#     'past future': 0.1,
#     'future past': 0.1,
#     'future present': 0.1},
#    'full_tense_seq': {'present past': 0.20833333333333334,
#     'past present': 0.20833333333333334,
#     'present present': 0.2916666666666667,
#     'past past': 0.041666666666666664,
#     'past future': 0.041666666666666664,
#     'future present': 0.08333333333333333,
#     'present future': 0.08333333333333333,
#     'future past': 0.041666666666666664}},
#   {'id': 'weather_news-21',
#    'sentence_tense_seq': {'future past': 0.11363636363636363,
#     'past future': 0.045454545454545456,
#     'future future': 0.09090909090909091,
#     'present present': 0.5681818181818182,
#     'present past': 0.045454545454545456,
#     'present future': 0.06818181818181818,
#     'future present': 0.06818181818181818},
#    'full_tense_seq': {'future past': 0.07936507936507936,
#     'past future': 0.047619047619047616,
#     'future future': 0.06349206349206349,
#     'past present': 0.06349206349206349,
#     'present present': 0.5238095238095238,
#     'present past': 0.031746031746031744,
#     'present future': 0.1111111111111111,
#     'future present': 0.07936507936507936}},
#   {'id': 'weather_news-22',
#    'sentence_tense_seq': {'present future': 0.125,
#     'future future': 0.25,
#     'future present': 0.375,
#     'present past': 0.125,
#     'present present': 0.125},
#    'full_tense_seq': {'future present': 0.2,
#     'present future': 0.16,
#     'future future': 0.48,
#     'present present': 0.08,
#     'present past': 0.04,
#     'past future': 0.04}},
#   {'id': 'weather_news-23', 'sentence_tense_seq': {}, 'full_tense_seq': {}},
#   {'id': 'weather_news-24',
#    'sentence_tense_seq': {'future present': 0.2153846153846154,
#     'present present': 0.4461538461538462,
#     'present future': 0.12307692307692308,
#     'future past': 0.06153846153846154,
#     'past present': 0.03076923076923077,
#     'present past': 0.07692307692307693,
#     'past future': 0.03076923076923077,
#     'past past': 0.015384615384615385},
#    'full_tense_seq': {'future future': 0.04504504504504504,
#     'future present': 0.1891891891891892,
#     'present present': 0.40540540540540543,
#     'present future': 0.18018018018018017,
#     'future past': 0.036036036036036036,
#     'past present': 0.04504504504504504,
#     'present past': 0.05405405405405406,
#     'past future': 0.036036036036036036,
#     'past past': 0.009009009009009009}},
#   {'id': 'weather_news-25',
#    'sentence_tense_seq': {'past present': 0.25,
#     'future present': 0.25,
#     'future future': 0.25,
#     'present present': 0.25},
#    'full_tense_seq': {'past past': 0.0625,
#     'past present': 0.0625,
#     'present future': 0.1875,
#     'future present': 0.125,
#     'future future': 0.5,
#     'present present': 0.0625}},
#   {'id': 'weather_news-26',
#    'sentence_tense_seq': {'past present': 0.2222222222222222,
#     'present past': 0.2222222222222222,
#     'present present': 0.3333333333333333,
#     'present future': 0.1111111111111111,
#     'future present': 0.1111111111111111},
#    'full_tense_seq': {'past present': 0.09090909090909091,
#     'present present': 0.7575757575757576,
#     'present past': 0.09090909090909091,
#     'present future': 0.030303030303030304,
#     'future present': 0.030303030303030304}},
#   {'id': 'weather_news-27',
#    'sentence_tense_seq': {'present past': 0.3157894736842105,
#     'past present': 0.10526315789473684,
#     'present present': 0.15789473684210525,
#     'past past': 0.3157894736842105,
#     'past future': 0.05263157894736842,
#     'future past': 0.05263157894736842},
#    'full_tense_seq': {'present past': 0.27586206896551724,
#     'past present': 0.2413793103448276,
#     'present present': 0.13793103448275862,
#     'past past': 0.27586206896551724,
#     'past future': 0.034482758620689655,
#     'future past': 0.034482758620689655}},
#   {'id': 'weather_news-28',
#    'sentence_tense_seq': {'past future': 0.044444444444444446,
#     'present past': 0.24444444444444444,
#     'past present': 0.06666666666666667,
#     'present future': 0.08888888888888889,
#     'future past': 0.13333333333333333,
#     'future present': 0.044444444444444446,
#     'past past': 0.2,
#     'present present': 0.17777777777777778},
#    'full_tense_seq': {'past future': 0.12048192771084337,
#     'future present': 0.10843373493975904,
#     'present future': 0.07228915662650602,
#     'present past': 0.1566265060240964,
#     'past present': 0.12048192771084337,
#     'present present': 0.13253012048192772,
#     'future past': 0.08433734939759036,
#     'past past': 0.1927710843373494,
#     'future future': 0.012048192771084338}},
#   {'id': 'weather_news-29',
#    'sentence_tense_seq': {'future past': 0.1,
#     'past present': 0.2,
#     'present past': 0.25,
#     'past future': 0.1,
#     'future present': 0.1,
#     'present future': 0.05,
#     'present present': 0.2},
#    'full_tense_seq': {'future past': 0.043478260869565216,
#     'past present': 0.15217391304347827,
#     'present present': 0.5,
#     'present past': 0.15217391304347827,
#     'past future': 0.043478260869565216,
#     'future present': 0.06521739130434782,
#     'present future': 0.043478260869565216}},
#   {'id': 'weather_news-30',
#    'sentence_tense_seq': {'present future': 0.09523809523809523,
#     'future past': 0.09523809523809523,
#     'present past': 0.23809523809523808,
#     'past present': 0.19047619047619047,
#     'future present': 0.047619047619047616,
#     'present present': 0.23809523809523808,
#     'past future': 0.047619047619047616,
#     'future future': 0.047619047619047616},
#    'full_tense_seq': {'present future': 0.1,
#     'future past': 0.05,
#     'past present': 0.175,
#     'present past': 0.2,
#     'past future': 0.05,
#     'future future': 0.125,
#     'present present': 0.2,
#     'future present': 0.1}},
#   {'id': 'weather_news-31',
#    'sentence_tense_seq': {'present present': 0.5,
#     'future past': 0.25,
#     'present past': 0.25},
#    'full_tense_seq': {'past present': 0.2727272727272727,
#     'present present': 0.2727272727272727,
#     'present future': 0.18181818181818182,
#     'future present': 0.09090909090909091,
#     'future past': 0.09090909090909091,
#     'present past': 0.09090909090909091}},
#   {'id': 'weather_news-32',
#    'sentence_tense_seq': {'past present': 0.18823529411764706,
#     'present present': 0.29411764705882354,
#     'future past': 0.047058823529411764,
#     'past past': 0.21176470588235294,
#     'present past': 0.24705882352941178,
#     'future present': 0.011764705882352941},
#    'full_tense_seq': {'present past': 0.21379310344827587,
#     'past present': 0.21379310344827587,
#     'present present': 0.33793103448275863,
#     'present future': 0.013793103448275862,
#     'future past': 0.027586206896551724,
#     'past past': 0.16551724137931034,
#     'past future': 0.020689655172413793,
#     'future present': 0.006896551724137931}},
#   {'id': 'weather_news-33',
#    'sentence_tense_seq': {'present past': 0.19047619047619047,
#     'present present': 0.5238095238095238,
#     'past past': 0.047619047619047616,
#     'past present': 0.09523809523809523,
#     'future future': 0.047619047619047616,
#     'future past': 0.047619047619047616,
#     'present future': 0.047619047619047616},
#    'full_tense_seq': {'present present': 0.43333333333333335,
#     'present past': 0.1,
#     'past present': 0.13333333333333333,
#     'past past': 0.03333333333333333,
#     'present future': 0.11666666666666667,
#     'future future': 0.08333333333333333,
#     'future present': 0.06666666666666667,
#     'future past': 0.03333333333333333}},
#   {'id': 'weather_news-34',
#    'sentence_tense_seq': {'present future': 0.047619047619047616,
#     'future present': 0.2857142857142857,
#     'future future': 0.09523809523809523,
#     'present present': 0.14285714285714285,
#     'present past': 0.14285714285714285,
#     'past present': 0.14285714285714285,
#     'past past': 0.09523809523809523,
#     'future past': 0.047619047619047616},
#    'full_tense_seq': {'present future': 0.1282051282051282,
#     'future present': 0.15384615384615385,
#     'future future': 0.1794871794871795,
#     'present present': 0.20512820512820512,
#     'present past': 0.10256410256410256,
#     'past present': 0.07692307692307693,
#     'past past': 0.07692307692307693,
#     'past future': 0.05128205128205128,
#     'future past': 0.02564102564102564}},
#   {'id': 'weather_news-35',
#    'sentence_tense_seq': {'present present': 0.6557377049180327,
#     'present past': 0.09836065573770492,
#     'future present': 0.03278688524590164,
#     'future future': 0.01639344262295082,
#     'present future': 0.040983606557377046,
#     'future past': 0.00819672131147541,
#     'past present': 0.10655737704918032,
#     'past past': 0.03278688524590164,
#     'past future': 0.00819672131147541},
#    'full_tense_seq': {'present present': 0.6231884057971014,
#     'present past': 0.0966183574879227,
#     'past future': 0.014492753623188406,
#     'future future': 0.03864734299516908,
#     'future present': 0.05314009661835749,
#     'present future': 0.04830917874396135,
#     'future past': 0.00966183574879227,
#     'past present': 0.09178743961352658,
#     'past past': 0.024154589371980676}},
#   {'id': 'weather_news-36',
#    'sentence_tense_seq': {'present present': 0.36507936507936506,
#     'past present': 0.15873015873015872,
#     'present past': 0.14285714285714285,
#     'future past': 0.015873015873015872,
#     'past past': 0.047619047619047616,
#     'past future': 0.031746031746031744,
#     'present future': 0.09523809523809523,
#     'future present': 0.1111111111111111,
#     'future future': 0.031746031746031744},
#    'full_tense_seq': {'present present': 0.3516483516483517,
#     'present past': 0.15384615384615385,
#     'past present': 0.14285714285714285,
#     'past future': 0.04395604395604396,
#     'future past': 0.03296703296703297,
#     'past past': 0.054945054945054944,
#     'present future': 0.08791208791208792,
#     'future present': 0.0989010989010989,
#     'future future': 0.03296703296703297}},
#   {'id': 'weather_news-37',
#    'sentence_tense_seq': {'present present': 0.3924050632911392,
#     'past present': 0.11392405063291139,
#     'present past': 0.0759493670886076,
#     'past past': 0.02531645569620253,
#     'past future': 0.08860759493670886,
#     'future past': 0.06329113924050633,
#     'future future': 0.0759493670886076,
#     'future present': 0.11392405063291139,
#     'present future': 0.05063291139240506},
#    'full_tense_seq': {'present present': 0.34579439252336447,
#     'present past': 0.11214953271028037,
#     'past present': 0.09345794392523364,
#     'past past': 0.028037383177570093,
#     'past future': 0.08411214953271028,
#     'future past': 0.06542056074766354,
#     'future future': 0.056074766355140186,
#     'future present': 0.11214953271028037,
#     'present future': 0.102803738317757}},
#   {'id': 'weather_news-38',
#    'sentence_tense_seq': {'future present': 0.19047619047619047,
#     'present past': 0.11904761904761904,
#     'past present': 0.14285714285714285,
#     'present present': 0.2619047619047619,
#     'future past': 0.023809523809523808,
#     'present future': 0.09523809523809523,
#     'past future': 0.11904761904761904,
#     'future future': 0.047619047619047616},
#    'full_tense_seq': {'present future': 0.07462686567164178,
#     'future present': 0.14925373134328357,
#     'present past': 0.1791044776119403,
#     'past present': 0.1044776119402985,
#     'present present': 0.23880597014925373,
#     'past future': 0.11940298507462686,
#     'future past': 0.04477611940298507,
#     'future future': 0.08955223880597014}},
#   {'id': 'weather_news-39',
#    'sentence_tense_seq': {'past past': 0.08333333333333333,
#     'present past': 0.3333333333333333,
#     'present present': 0.16666666666666666,
#     'past present': 0.125,
#     'future future': 0.041666666666666664,
#     'future past': 0.041666666666666664,
#     'past future': 0.08333333333333333,
#     'future present': 0.08333333333333333,
#     'present future': 0.041666666666666664},
#    'full_tense_seq': {'past past': 0.06,
#     'past present': 0.18,
#     'present present': 0.26,
#     'present past': 0.18,
#     'present future': 0.08,
#     'future present': 0.1,
#     'future future': 0.04,
#     'future past': 0.04,
#     'past future': 0.06}},
#   {'id': 'weather_news-40',
#    'sentence_tense_seq': {'past future': 0.14285714285714285,
#     'future past': 0.2857142857142857,
#     'past present': 0.14285714285714285,
#     'future future': 0.2857142857142857,
#     'present future': 0.14285714285714285},
#    'full_tense_seq': {'past future': 0.02127659574468085,
#     'future past': 0.0425531914893617,
#     'past present': 0.0851063829787234,
#     'present future': 0.0851063829787234,
#     'present present': 0.6382978723404256,
#     'future present': 0.06382978723404255,
#     'future future': 0.02127659574468085,
#     'present past': 0.0425531914893617}},
#   {'id': 'weather_news-41',
#    'sentence_tense_seq': {'present present': 0.5806451612903226,
#     'present past': 0.16129032258064516,
#     'past past': 0.06451612903225806,
#     'past present': 0.12903225806451613,
#     'present future': 0.03225806451612903,
#     'future present': 0.03225806451612903},
#    'full_tense_seq': {'present present': 0.5272727272727272,
#     'present past': 0.16363636363636364,
#     'past past': 0.05454545454545454,
#     'past present': 0.18181818181818182,
#     'present future': 0.03636363636363636,
#     'future present': 0.01818181818181818,
#     'future past': 0.01818181818181818}},
#   {'id': 'weather_news-42',
#    'sentence_tense_seq': {'present future': 0.5, 'future past': 0.5},
#    'full_tense_seq': {'future future': 0.23076923076923078,
#     'future present': 0.3076923076923077,
#     'present future': 0.3076923076923077,
#     'future past': 0.07692307692307693,
#     'past present': 0.07692307692307693}},
#   {'id': 'weather_news-43',
#    'sentence_tense_seq': {'past future': 0.25,
#     'future past': 0.5,
#     'past present': 0.25},
#    'full_tense_seq': {'past future': 0.025,
#     'future past': 0.05,
#     'past present': 0.075,
#     'present future': 0.05,
#     'present present': 0.75,
#     'present past': 0.025,
#     'future present': 0.025}},
#   {'id': 'weather_news-44',
#    'sentence_tense_seq': {'present past': 0.23529411764705882,
#     'present present': 0.4852941176470588,
#     'future present': 0.04411764705882353,
#     'past past': 0.08823529411764706,
#     'past present': 0.10294117647058823,
#     'future past': 0.014705882352941176,
#     'present future': 0.014705882352941176,
#     'past future': 0.014705882352941176},
#    'full_tense_seq': {'present past': 0.144,
#     'past present': 0.136,
#     'present present': 0.584,
#     'present future': 0.032,
#     'future present': 0.032,
#     'past past': 0.056,
#     'future past': 0.008,
#     'past future': 0.008}},
#   {'id': 'weather_news-45',
#    'sentence_tense_seq': {'present present': 0.6153846153846154,
#     'past past': 0.15384615384615385,
#     'past future': 0.07692307692307693,
#     'present future': 0.07692307692307693,
#     'future past': 0.07692307692307693},
#    'full_tense_seq': {'present present': 0.6451612903225806,
#     'present past': 0.06451612903225806,
#     'past past': 0.0967741935483871,
#     'past future': 0.06451612903225806,
#     'future present': 0.06451612903225806,
#     'present future': 0.03225806451612903,
#     'future past': 0.03225806451612903}},
#   {'id': 'weather_news-46',
#    'sentence_tense_seq': {'present present': 0.3333333333333333,
#     'present past': 0.17857142857142858,
#     'past present': 0.14285714285714285,
#     'present future': 0.08333333333333333,
#     'future present': 0.047619047619047616,
#     'past past': 0.10714285714285714,
#     'future future': 0.023809523809523808,
#     'future past': 0.07142857142857142,
#     'past future': 0.011904761904761904},
#    'full_tense_seq': {'present present': 0.373134328358209,
#     'present future': 0.06467661691542288,
#     'future present': 0.03980099502487562,
#     'present past': 0.12437810945273632,
#     'past present': 0.14427860696517414,
#     'future future': 0.029850746268656716,
#     'past past': 0.15422885572139303,
#     'future past': 0.04477611940298507,
#     'past future': 0.024875621890547265}},
#   {'id': 'weather_news-47',
#    'sentence_tense_seq': {'present present': 0.17105263157894737,
#     'present past': 0.2894736842105263,
#     'past past': 0.25,
#     'past present': 0.2894736842105263},
#    'full_tense_seq': {'present present': 0.22758620689655173,
#     'present past': 0.2482758620689655,
#     'past present': 0.2413793103448276,
#     'past past': 0.2689655172413793,
#     'past future': 0.006896551724137931,
#     'future present': 0.006896551724137931}},
#   {'id': 'weather_news-48',
#    'sentence_tense_seq': {'present present': 0.5416666666666666,
#     'present future': 0.08333333333333333,
#     'future present': 0.125,
#     'past future': 0.041666666666666664,
#     'future future': 0.041666666666666664,
#     'future past': 0.08333333333333333,
#     'present past': 0.041666666666666664,
#     'past present': 0.041666666666666664},
#    'full_tense_seq': {'past past': 0.03278688524590164,
#     'past present': 0.06557377049180328,
#     'present present': 0.4918032786885246,
#     'present past': 0.04918032786885246,
#     'present future': 0.11475409836065574,
#     'future present': 0.11475409836065574,
#     'future past': 0.04918032786885246,
#     'past future': 0.04918032786885246,
#     'future future': 0.03278688524590164}},
#   {'id': 'weather_news-49',
#    'sentence_tense_seq': {'present present': 0.47058823529411764,
#     'past past': 0.1568627450980392,
#     'past present': 0.13725490196078433,
#     'present past': 0.18627450980392157,
#     'past future': 0.029411764705882353,
#     'future past': 0.0196078431372549},
#    'full_tense_seq': {'present present': 0.45454545454545453,
#     'present past': 0.17482517482517482,
#     'past past': 0.13286713286713286,
#     'past present': 0.16783216783216784,
#     'past future': 0.027972027972027972,
#     'future past': 0.02097902097902098,
#     'future present': 0.013986013986013986,
#     'present future': 0.006993006993006993}},
#   {'id': 'weather_news-50',
#    'sentence_tense_seq': {'present present': 0.1111111111111111,
#     'past past': 0.2777777777777778,
#     'future present': 0.1111111111111111,
#     'past future': 0.05555555555555555,
#     'present past': 0.2777777777777778,
#     'future past': 0.05555555555555555,
#     'past present': 0.1111111111111111},
#    'full_tense_seq': {'present present': 0.11428571428571428,
#     'present past': 0.2,
#     'past past': 0.2857142857142857,
#     'past future': 0.11428571428571428,
#     'future future': 0.05714285714285714,
#     'future present': 0.05714285714285714,
#     'future past': 0.05714285714285714,
#     'past present': 0.11428571428571428}},
#   {'id': 'weather_news-51',
#    'sentence_tense_seq': {'past future': 0.07692307692307693,
#     'future present': 0.3076923076923077,
#     'present present': 0.07692307692307693,
#     'future future': 0.23076923076923078,
#     'present past': 0.15384615384615385,
#     'past past': 0.15384615384615385},
#    'full_tense_seq': {'past future': 0.08695652173913043,
#     'future present': 0.30434782608695654,
#     'present future': 0.21739130434782608,
#     'present present': 0.08695652173913043,
#     'future future': 0.13043478260869565,
#     'present past': 0.08695652173913043,
#     'past past': 0.08695652173913043}},
#   {'id': 'weather_news-52',
#    'sentence_tense_seq': {'future present': 0.5,
#     'future past': 0.25,
#     'past past': 0.125,
#     'past present': 0.125},
#    'full_tense_seq': {'future future': 0.2631578947368421,
#     'future present': 0.21052631578947367,
#     'present future': 0.21052631578947367,
#     'present present': 0.05263157894736842,
#     'future past': 0.10526315789473684,
#     'past past': 0.05263157894736842,
#     'past present': 0.05263157894736842,
#     'past future': 0.05263157894736842}},
#   {'id': 'weather_news-53',
#    'sentence_tense_seq': {'present present': 0.4444444444444444,
#     'present past': 0.2222222222222222,
#     'past past': 0.1111111111111111,
#     'past present': 0.16666666666666666,
#     'future past': 0.05555555555555555},
#    'full_tense_seq': {'present present': 0.41935483870967744,
#     'present past': 0.1935483870967742,
#     'past past': 0.12903225806451613,
#     'past present': 0.1935483870967742,
#     'past future': 0.03225806451612903,
#     'future past': 0.03225806451612903}},
#   {'id': 'weather_news-54',
#    'sentence_tense_seq': {'past present': 0.14285714285714285,
#     'present past': 0.19047619047619047,
#     'present present': 0.5476190476190477,
#     'present future': 0.023809523809523808,
#     'future present': 0.047619047619047616,
#     'past past': 0.047619047619047616},
#    'full_tense_seq': {'past present': 0.2,
#     'present past': 0.18333333333333332,
#     'present present': 0.5166666666666667,
#     'present future': 0.03333333333333333,
#     'future present': 0.03333333333333333,
#     'past past': 0.03333333333333333}},
#   {'id': 'weather_news-55',
#    'sentence_tense_seq': {'present present': 0.5238095238095238,
#     'present past': 0.19047619047619047,
#     'past present': 0.14285714285714285,
#     'past future': 0.047619047619047616,
#     'future present': 0.047619047619047616,
#     'future past': 0.047619047619047616},
#    'full_tense_seq': {'present present': 0.4782608695652174,
#     'present past': 0.17391304347826086,
#     'past present': 0.17391304347826086,
#     'past future': 0.043478260869565216,
#     'future present': 0.043478260869565216,
#     'present future': 0.043478260869565216,
#     'future past': 0.043478260869565216}},
#   {'id': 'weather_news-56',
#    'sentence_tense_seq': {'present past': 0.35294117647058826,
#     'present present': 0.29411764705882354,
#     'future past': 0.058823529411764705,
#     'past future': 0.058823529411764705,
#     'past past': 0.11764705882352941,
#     'present future': 0.058823529411764705,
#     'future present': 0.058823529411764705},
#    'full_tense_seq': {'present present': 0.25,
#     'present past': 0.25,
#     'past present': 0.19444444444444445,
#     'past future': 0.08333333333333333,
#     'future past': 0.027777777777777776,
#     'future present': 0.08333333333333333,
#     'past past': 0.08333333333333333,
#     'present future': 0.027777777777777776}},
#   {'id': 'weather_news-57',
#    'sentence_tense_seq': {'past future': 0.2,
#     'future past': 0.4,
#     'past present': 0.2,
#     'present present': 0.2},
#    'full_tense_seq': {'past future': 0.029411764705882353,
#     'future past': 0.058823529411764705,
#     'past present': 0.11764705882352941,
#     'present future': 0.17647058823529413,
#     'present present': 0.4411764705882353,
#     'future present': 0.11764705882352941,
#     'present past': 0.058823529411764705}},
#   {'id': 'weather_news-58',
#    'sentence_tense_seq': {'present present': 0.43636363636363634,
#     'past future': 0.03636363636363636,
#     'past present': 0.14545454545454545,
#     'present future': 0.09090909090909091,
#     'past past': 0.03636363636363636,
#     'future past': 0.05454545454545454,
#     'future present': 0.03636363636363636,
#     'present past': 0.16363636363636364},
#    'full_tense_seq': {'present present': 0.45454545454545453,
#     'present past': 0.14545454545454545,
#     'past present': 0.16363636363636364,
#     'past future': 0.03636363636363636,
#     'future past': 0.05454545454545454,
#     'present future': 0.06363636363636363,
#     'past past': 0.02727272727272727,
#     'future present': 0.045454545454545456,
#     'future future': 0.00909090909090909}},
#   {'id': 'weather_news-59',
#    'sentence_tense_seq': {'future future': 0.029411764705882353,
#     'future present': 0.08823529411764706,
#     'present present': 0.23529411764705882,
#     'present past': 0.20588235294117646,
#     'past present': 0.14705882352941177,
#     'present future': 0.058823529411764705,
#     'past future': 0.08823529411764706,
#     'past past': 0.14705882352941177},
#    'full_tense_seq': {'past present': 0.12307692307692308,
#     'present present': 0.35384615384615387,
#     'present future': 0.07692307692307693,
#     'future future': 0.015384615384615385,
#     'future present': 0.07692307692307693,
#     'present past': 0.12307692307692308,
#     'future past': 0.06153846153846154,
#     'past past': 0.1076923076923077,
#     'past future': 0.06153846153846154}},
#   {'id': 'weather_news-60',
#    'sentence_tense_seq': {'future future': 0.022618145059388424,
#     'present past': 0.18334596916856205,
#     'present present': 0.33421784179934294,
#     'past past': 0.12661106899166036,
#     'past future': 0.02982057113975234,
#     'future past': 0.03879201415213546,
#     'future present': 0.06696992671215567,
#     'past present': 0.13457164518574677,
#     'present future': 0.063052817791256},
#    'full_tense_seq': {'future future': 0.03766828988828416,
#     'future present': 0.07812947579490118,
#     'present past': 0.14472930392437697,
#     'past present': 0.14100544256659983,
#     'present future': 0.07440561443712403,
#     'present present': 0.35183328559152105,
#     'past past': 0.10663133772558006,
#     'past future': 0.03466055571469493,
#     'future past': 0.030936694356917788}},
#   {'id': 'weather_news-61',
#    'sentence_tense_seq': {'past past': 0.4090909090909091,
#     'present past': 0.3181818181818182,
#     'past future': 0.13636363636363635,
#     'future past': 0.045454545454545456,
#     'future present': 0.045454545454545456,
#     'past present': 0.045454545454545456},
#    'full_tense_seq': {'past past': 0.41025641025641024,
#     'past present': 0.1282051282051282,
#     'present past': 0.1794871794871795,
#     'past future': 0.10256410256410256,
#     'future past': 0.02564102564102564,
#     'present future': 0.02564102564102564,
#     'future present': 0.07692307692307693,
#     'present present': 0.05128205128205128}},
#   {'id': 'weather_news-62',
#    'sentence_tense_seq': {'past future': 0.16666666666666666,
#     'future past': 0.3333333333333333,
#     'past present': 0.16666666666666666,
#     'present present': 0.3333333333333333},
#    'full_tense_seq': {'past future': 0.043478260869565216,
#     'future past': 0.08695652173913043,
#     'past present': 0.13043478260869565,
#     'present future': 0.13043478260869565,
#     'present present': 0.4782608695652174,
#     'future present': 0.08695652173913043,
#     'present past': 0.043478260869565216}},
#   {'id': 'weather_news-63',
#    'sentence_tense_seq': {'present present': 0.3333333333333333,
#     'future present': 0.25,
#     'future future': 0.25,
#     'future past': 0.08333333333333333,
#     'past future': 0.08333333333333333},
#    'full_tense_seq': {'present present': 0.2413793103448276,
#     'present future': 0.20689655172413793,
#     'future present': 0.20689655172413793,
#     'future future': 0.27586206896551724,
#     'future past': 0.034482758620689655,
#     'past future': 0.034482758620689655}},
#   {'id': 'weather_news-64',
#    'sentence_tense_seq': {'present present': 0.5555555555555556,
#     'present future': 0.1111111111111111,
#     'future present': 0.1111111111111111,
#     'future past': 0.1111111111111111,
#     'past past': 0.1111111111111111},
#    'full_tense_seq': {'present present': 0.4,
#     'present past': 0.08,
#     'past present': 0.04,
#     'present future': 0.08,
#     'future future': 0.2,
#     'future present': 0.08,
#     'past future': 0.04,
#     'future past': 0.04,
#     'past past': 0.04}},
#   {'id': 'weather_news-65',
#    'sentence_tense_seq': {'present present': 0.42857142857142855,
#     'present past': 0.35714285714285715,
#     'past present': 0.14285714285714285,
#     'past past': 0.07142857142857142},
#    'full_tense_seq': {'present present': 0.5106382978723404,
#     'present past': 0.2127659574468085,
#     'past present': 0.2127659574468085,
#     'past past': 0.06382978723404255}},
#   {'id': 'weather_news-66',
#    'sentence_tense_seq': {'past present': 0.3333333333333333,
#     'future present': 0.16666666666666666,
#     'present present': 0.16666666666666666,
#     'future past': 0.16666666666666666,
#     'past past': 0.16666666666666666},
#    'full_tense_seq': {'present present': 0.19047619047619047,
#     'present past': 0.09523809523809523,
#     'past past': 0.14285714285714285,
#     'past present': 0.14285714285714285,
#     'present future': 0.09523809523809523,
#     'future present': 0.047619047619047616,
#     'future future': 0.14285714285714285,
#     'future past': 0.09523809523809523,
#     'past future': 0.047619047619047616}},
#   {'id': 'weather_news-67',
#    'sentence_tense_seq': {'present present': 0.38095238095238093,
#     'present past': 0.23809523809523808,
#     'present future': 0.14285714285714285,
#     'past present': 0.19047619047619047,
#     'future past': 0.047619047619047616},
#    'full_tense_seq': {'present present': 0.4883720930232558,
#     'present past': 0.13953488372093023,
#     'past present': 0.16279069767441862,
#     'present future': 0.09302325581395349,
#     'future future': 0.023255813953488372,
#     'future present': 0.06976744186046512,
#     'future past': 0.023255813953488372}},
#   {'id': 'weather_news-68',
#    'sentence_tense_seq': {'past present': 0.17391304347826086,
#     'present past': 0.391304347826087,
#     'past past': 0.13043478260869565,
#     'past future': 0.043478260869565216,
#     'future past': 0.043478260869565216,
#     'present present': 0.21739130434782608},
#    'full_tense_seq': {'past past': 0.1111111111111111,
#     'past present': 0.3055555555555556,
#     'present past': 0.3055555555555556,
#     'past future': 0.027777777777777776,
#     'future past': 0.027777777777777776,
#     'present present': 0.2222222222222222}},
#   {'id': 'weather_news-69',
#    'sentence_tense_seq': {'present present': 0.4,
#     'present past': 0.2,
#     'past past': 0.2,
#     'past present': 0.1,
#     'future past': 0.1},
#    'full_tense_seq': {'present present': 0.4166666666666667,
#     'present past': 0.16666666666666666,
#     'past present': 0.16666666666666666,
#     'past past': 0.16666666666666666,
#     'past future': 0.041666666666666664,
#     'future past': 0.041666666666666664}},
#   {'id': 'weather_news-70',
#    'sentence_tense_seq': {'present present': 0.8, 'present past': 0.2},
#    'full_tense_seq': {'present present': 0.7857142857142857,
#     'present past': 0.10714285714285714,
#     'past present': 0.10714285714285714}},
#   {'id': 'weather_news-71',
#    'sentence_tense_seq': {'past present': 0.08695652173913043,
#     'present present': 0.17391304347826086,
#     'present future': 0.21739130434782608,
#     'future present': 0.21739130434782608,
#     'present past': 0.13043478260869565,
#     'future past': 0.08695652173913043,
#     'future future': 0.08695652173913043},
#    'full_tense_seq': {'present past': 0.09302325581395349,
#     'past present': 0.046511627906976744,
#     'present present': 0.18604651162790697,
#     'present future': 0.16279069767441862,
#     'future present': 0.20930232558139536,
#     'past future': 0.11627906976744186,
#     'future past': 0.06976744186046512,
#     'future future': 0.11627906976744186}},
#   {'id': 'weather_news-72',
#    'sentence_tense_seq': {'past future': 0.16666666666666666,
#     'future past': 0.3333333333333333,
#     'past present': 0.16666666666666666,
#     'future future': 0.16666666666666666,
#     'present present': 0.16666666666666666},
#    'full_tense_seq': {'past future': 0.05,
#     'future past': 0.1,
#     'past present': 0.2,
#     'present future': 0.15,
#     'present present': 0.35,
#     'future present': 0.05,
#     'present past': 0.1}},
#   {'id': 'weather_news-73',
#    'sentence_tense_seq': {'present present': 0.15151515151515152,
#     'future past': 0.21212121212121213,
#     'present future': 0.030303030303030304,
#     'past past': 0.030303030303030304,
#     'past present': 0.09090909090909091,
#     'present past': 0.24242424242424243,
#     'past future': 0.15151515151515152,
#     'future present': 0.09090909090909091},
#    'full_tense_seq': {'present present': 0.109375,
#     'present future': 0.09375,
#     'future past': 0.140625,
#     'past present': 0.15625,
#     'past past': 0.03125,
#     'past future': 0.15625,
#     'present past': 0.171875,
#     'future future': 0.046875,
#     'future present': 0.09375}},
#   {'id': 'weather_news-74',
#    'sentence_tense_seq': {'past past': 0.4,
#     'past future': 0.06666666666666667,
#     'future present': 0.06666666666666667,
#     'present past': 0.13333333333333333,
#     'past present': 0.26666666666666666,
#     'present present': 0.06666666666666667},
#    'full_tense_seq': {'present past': 0.2,
#     'past past': 0.4,
#     'past future': 0.04,
#     'future present': 0.04,
#     'present present': 0.08,
#     'past present': 0.16,
#     'present future': 0.04,
#     'future past': 0.04}},
#   {'id': 'weather_news-75',
#    'sentence_tense_seq': {'present future': 0.18181818181818182,
#     'present present': 0.36363636363636365,
#     'future future': 0.09090909090909091,
#     'future present': 0.18181818181818182,
#     'past past': 0.09090909090909091,
#     'future past': 0.045454545454545456,
#     'present past': 0.045454545454545456},
#    'full_tense_seq': {'present present': 0.24,
#     'present future': 0.2,
#     'future present': 0.22,
#     'future future': 0.14,
#     'present past': 0.06,
#     'past present': 0.04,
#     'past past': 0.04,
#     'future past': 0.02,
#     'past future': 0.04}},
#   {'id': 'weather_news-76',
#    'sentence_tense_seq': {'present future': 0.2727272727272727,
#     'future present': 0.45454545454545453,
#     'present present': 0.2727272727272727},
#    'full_tense_seq': {'present future': 0.2857142857142857,
#     'future future': 0.14285714285714285,
#     'future present': 0.2857142857142857,
#     'present present': 0.2857142857142857}},
#   {'id': 'weather_news-77',
#    'sentence_tense_seq': {'present past': 0.2,
#     'past present': 0.05,
#     'present present': 0.275,
#     'past past': 0.125,
#     'past future': 0.075,
#     'future present': 0.125,
#     'present future': 0.125,
#     'future future': 0.025},
#    'full_tense_seq': {'present past': 0.1044776119402985,
#     'past past': 0.08955223880597014,
#     'past present': 0.08955223880597014,
#     'present present': 0.31343283582089554,
#     'present future': 0.13432835820895522,
#     'future past': 0.029850746268656716,
#     'past future': 0.04477611940298507,
#     'future present': 0.13432835820895522,
#     'future future': 0.05970149253731343}},
#   {'id': 'weather_news-78',
#    'sentence_tense_seq': {'past future': 0.2,
#     'future past': 0.4,
#     'past present': 0.2,
#     'present present': 0.2},
#    'full_tense_seq': {'past future': 0.043478260869565216,
#     'future past': 0.08695652173913043,
#     'past present': 0.08695652173913043,
#     'present future': 0.17391304347826086,
#     'present present': 0.5217391304347826,
#     'future present': 0.08695652173913043}},
#   {'id': 'weather_news-79',
#    'sentence_tense_seq': {'past present': 0.14084507042253522,
#     'past future': 0.01056338028169014,
#     'present past': 0.15140845070422534,
#     'present present': 0.5140845070422535,
#     'present future': 0.06690140845070422,
#     'future present': 0.06690140845070422,
#     'past past': 0.02464788732394366,
#     'future past': 0.02112676056338028,
#     'future future': 0.0035211267605633804},
#    'full_tense_seq': {'present past': 0.1185682326621924,
#     'past present': 0.12527964205816555,
#     'past future': 0.008948545861297539,
#     'future present': 0.07158836689038031,
#     'present present': 0.5615212527964206,
#     'present future': 0.07829977628635347,
#     'past past': 0.015659955257270694,
#     'future past': 0.015659955257270694,
#     'future future': 0.0044742729306487695}},
#   {'id': 'weather_news-80',
#    'sentence_tense_seq': {'present past': 0.16363636363636364,
#     'present future': 0.09454545454545454,
#     'past past': 0.04727272727272727,
#     'past present': 0.11636363636363636,
#     'present present': 0.4290909090909091,
#     'future present': 0.06545454545454546,
#     'future past': 0.01818181818181818,
#     'future future': 0.025454545454545455,
#     'past future': 0.04},
#    'full_tense_seq': {'present past': 0.14251207729468598,
#     'past present': 0.12318840579710146,
#     'present future': 0.0748792270531401,
#     'future present': 0.09420289855072464,
#     'present present': 0.4323671497584541,
#     'past future': 0.03864734299516908,
#     'past past': 0.04589371980676329,
#     'future past': 0.01932367149758454,
#     'future future': 0.028985507246376812}},
#   {'id': 'weather_news-81',
#    'sentence_tense_seq': {'present past': 0.14634146341463414,
#     'past present': 0.14634146341463414,
#     'present present': 0.21951219512195122,
#     'past past': 0.12195121951219512,
#     'future past': 0.1951219512195122,
#     'past future': 0.04878048780487805,
#     'future present': 0.07317073170731707,
#     'present future': 0.04878048780487805},
#    'full_tense_seq': {'past present': 0.19047619047619047,
#     'present present': 0.25,
#     'present future': 0.11904761904761904,
#     'future present': 0.07142857142857142,
#     'present past': 0.14285714285714285,
#     'past past': 0.07142857142857142,
#     'future past': 0.09523809523809523,
#     'past future': 0.047619047619047616,
#     'future future': 0.011904761904761904}},
#   {'id': 'weather_news-82',
#    'sentence_tense_seq': {'present present': 0.1689497716894977,
#     'present past': 0.2146118721461187,
#     'past present': 0.2328767123287671,
#     'past past': 0.2557077625570776,
#     'future past': 0.0365296803652968,
#     'present future': 0.0319634703196347,
#     'future present': 0.0319634703196347,
#     'past future': 0.0182648401826484,
#     'future future': 0.0091324200913242},
#    'full_tense_seq': {'present present': 0.1746031746031746,
#     'present past': 0.21904761904761905,
#     'past present': 0.22857142857142856,
#     'past past': 0.25396825396825395,
#     'past future': 0.022222222222222223,
#     'future past': 0.031746031746031744,
#     'present future': 0.0380952380952381,
#     'future present': 0.025396825396825397,
#     'future future': 0.006349206349206349}},
#   {'id': 'weather_news-83',
#    'sentence_tense_seq': {'future past': 0.12280701754385964,
#     'past present': 0.08771929824561403,
#     'present future': 0.10526315789473684,
#     'present present': 0.24561403508771928,
#     'present past': 0.2807017543859649,
#     'past past': 0.05263157894736842,
#     'future present': 0.05263157894736842,
#     'past future': 0.05263157894736842},
# ...
#     'past past': 0.375,
#     'past future': 0.03125,
#     'future past': 0.03125}},
#   {'id': 'crime_news-969',
#    'sentence_tense_seq': {'past present': 0.21875,
#     'present past': 0.1875,
#     'past past': 0.375,
#     'present present': 0.125,
#     'future past': 0.0625,
#     'past future': 0.03125},
#    'full_tense_seq': {'past present': 0.22727272727272727,
#     'present present': 0.1590909090909091,
#     'present past': 0.20454545454545456,
#     'past past': 0.3181818181818182,
#     'past future': 0.045454545454545456,
#     'future past': 0.045454545454545456}},
#   {'id': 'crime_news-970',
#    'sentence_tense_seq': {'past past': 0.3023255813953488,
#     'past present': 0.18604651162790697,
#     'present present': 0.3023255813953488,
#     'present past': 0.20930232558139536},
#    'full_tense_seq': {'past past': 0.3333333333333333,
#     'past present': 0.2037037037037037,
#     'present present': 0.25925925925925924,
#     'present past': 0.2037037037037037}},
#   {'id': 'crime_news-971',
#    'sentence_tense_seq': {'past present': 0.0975609756097561,
#     'past past': 0.8292682926829268,
#     'present past': 0.04878048780487805,
#     'future past': 0.024390243902439025},
#    'full_tense_seq': {'past present': 0.07547169811320754,
#     'present past': 0.07547169811320754,
#     'past past': 0.8113207547169812,
#     'past future': 0.018867924528301886,
#     'future past': 0.018867924528301886}},
#   {'id': 'crime_news-972',
#    'sentence_tense_seq': {'past past': 0.41509433962264153,
#     'past present': 0.20754716981132076,
#     'present present': 0.09433962264150944,
#     'present future': 0.018867924528301886,
#     'future past': 0.03773584905660377,
#     'present past': 0.22641509433962265},
#    'full_tense_seq': {'past past': 0.4492753623188406,
#     'past present': 0.21739130434782608,
#     'present present': 0.08695652173913043,
#     'present future': 0.014492753623188406,
#     'future past': 0.028985507246376812,
#     'present past': 0.18840579710144928,
#     'past future': 0.014492753623188406}},
#   {'id': 'crime_news-973',
#    'sentence_tense_seq': {'past past': 0.1,
#     'past present': 0.2,
#     'present past': 0.15,
#     'present present': 0.35,
#     'past future': 0.05,
#     'future past': 0.1,
#     'present future': 0.05},
#    'full_tense_seq': {'past past': 0.2413793103448276,
#     'past present': 0.1724137931034483,
#     'present past': 0.10344827586206896,
#     'present present': 0.3448275862068966,
#     'past future': 0.034482758620689655,
#     'future past': 0.06896551724137931,
#     'present future': 0.034482758620689655}},
#   {'id': 'crime_news-974',
#    'sentence_tense_seq': {'past past': 0.40298507462686567,
#     'past present': 0.29850746268656714,
#     'present past': 0.14925373134328357,
#     'present present': 0.08955223880597014,
#     'future past': 0.04477611940298507,
#     'past future': 0.014925373134328358},
#    'full_tense_seq': {'past past': 0.41509433962264153,
#     'past present': 0.20754716981132076,
#     'present past': 0.19811320754716982,
#     'past future': 0.03773584905660377,
#     'future past': 0.04716981132075472,
#     'present present': 0.0660377358490566,
#     'present future': 0.018867924528301886,
#     'future present': 0.009433962264150943}},
#   {'id': 'crime_news-975',
#    'sentence_tense_seq': {'past past': 0.3137254901960784,
#     'present present': 0.17647058823529413,
#     'present past': 0.19607843137254902,
#     'past present': 0.27450980392156865,
#     'present future': 0.0196078431372549,
#     'future past': 0.0196078431372549},
#    'full_tense_seq': {'past past': 0.30952380952380953,
#     'past present': 0.27380952380952384,
#     'present present': 0.14285714285714285,
#     'present past': 0.25,
#     'present future': 0.011904761904761904,
#     'future past': 0.011904761904761904}},
#   {'id': 'crime_news-976',
#    'sentence_tense_seq': {'past past': 0.5853658536585366,
#     'past present': 0.12195121951219512,
#     'present present': 0.0975609756097561,
#     'present past': 0.0975609756097561,
#     'past future': 0.04878048780487805,
#     'future present': 0.024390243902439025,
#     'future past': 0.024390243902439025},
#    'full_tense_seq': {'past past': 0.5535714285714286,
#     'past present': 0.14285714285714285,
#     'present present': 0.07142857142857142,
#     'present past': 0.16071428571428573,
#     'past future': 0.03571428571428571,
#     'future present': 0.017857142857142856,
#     'future past': 0.017857142857142856}},
#   {'id': 'crime_news-977',
#    'sentence_tense_seq': {'past present': 0.18181818181818182,
#     'present past': 0.18181818181818182,
#     'present present': 0.36363636363636365,
#     'present future': 0.09090909090909091,
#     'future past': 0.045454545454545456,
#     'past past': 0.13636363636363635},
#    'full_tense_seq': {'past present': 0.19444444444444445,
#     'present past': 0.19444444444444445,
#     'present present': 0.3333333333333333,
#     'present future': 0.05555555555555555,
#     'future present': 0.05555555555555555,
#     'past past': 0.16666666666666666}},
#   {'id': 'crime_news-978',
#    'sentence_tense_seq': {'past present': 0.23529411764705882,
#     'present past': 0.23529411764705882,
#     'past past': 0.4411764705882353,
#     'present present': 0.08823529411764706},
#    'full_tense_seq': {'past present': 0.1836734693877551,
#     'present past': 0.1836734693877551,
#     'past past': 0.5306122448979592,
#     'present present': 0.10204081632653061}},
#   {'id': 'crime_news-979',
#    'sentence_tense_seq': {'past past': 0.7368421052631579,
#     'past present': 0.10526315789473684,
#     'present past': 0.15789473684210525},
#    'full_tense_seq': {'past past': 0.7307692307692307,
#     'past present': 0.15384615384615385,
#     'present past': 0.11538461538461539}},
#   {'id': 'crime_news-980',
#    'sentence_tense_seq': {'present past': 0.1651376146788991,
#     'past past': 0.45871559633027525,
#     'past present': 0.2018348623853211,
#     'present present': 0.1559633027522936,
#     'past future': 0.009174311926605505,
#     'future past': 0.009174311926605505},
#    'full_tense_seq': {'present past': 0.20408163265306123,
#     'past past': 0.42857142857142855,
#     'past present': 0.19727891156462585,
#     'present present': 0.14285714285714285,
#     'past future': 0.006802721088435374,
#     'future present': 0.006802721088435374,
#     'present future': 0.006802721088435374,
#     'future past': 0.006802721088435374}},
#   {'id': 'crime_news-981',
#    'sentence_tense_seq': {'past past': 0.42857142857142855,
#     'past present': 0.14285714285714285,
#     'present past': 0.23809523809523808,
#     'future past': 0.09523809523809523,
#     'past future': 0.047619047619047616,
#     'present present': 0.047619047619047616},
#    'full_tense_seq': {'past past': 0.39285714285714285,
#     'past present': 0.21428571428571427,
#     'present present': 0.07142857142857142,
#     'present past': 0.17857142857142858,
#     'present future': 0.03571428571428571,
#     'future past': 0.07142857142857142,
#     'past future': 0.03571428571428571}},
#   {'id': 'crime_news-982',
#    'sentence_tense_seq': {'past past': 0.43902439024390244,
#     'past present': 0.14634146341463414,
#     'present past': 0.21951219512195122,
#     'present present': 0.14634146341463414,
#     'past future': 0.012195121951219513,
#     'future past': 0.012195121951219513,
#     'present future': 0.012195121951219513,
#     'future present': 0.012195121951219513},
#    'full_tense_seq': {'past past': 0.408,
#     'past present': 0.192,
#     'present past': 0.184,
#     'present present': 0.184,
#     'past future': 0.008,
#     'future past': 0.008,
#     'present future': 0.008,
#     'future present': 0.008}},
#   {'id': 'crime_news-983',
#    'sentence_tense_seq': {'past past': 0.4878048780487805,
#     'present past': 0.14634146341463414,
#     'past present': 0.2682926829268293,
#     'present future': 0.024390243902439025,
#     'future past': 0.024390243902439025,
#     'present present': 0.04878048780487805},
#    'full_tense_seq': {'past past': 0.4642857142857143,
#     'past present': 0.25,
#     'present past': 0.21428571428571427,
#     'present future': 0.017857142857142856,
#     'future past': 0.017857142857142856,
#     'present present': 0.03571428571428571}},
#   {'id': 'crime_news-984',
#    'sentence_tense_seq': {'present present': 0.1891891891891892,
#     'present past': 0.17567567567567569,
#     'past past': 0.4594594594594595,
#     'past present': 0.13513513513513514,
#     'past future': 0.013513513513513514,
#     'future past': 0.013513513513513514,
#     'present future': 0.013513513513513514},
#    'full_tense_seq': {'present present': 0.18095238095238095,
#     'present past': 0.17142857142857143,
#     'past past': 0.4380952380952381,
#     'past present': 0.17142857142857143,
#     'past future': 0.009523809523809525,
#     'future past': 0.009523809523809525,
#     'present future': 0.009523809523809525,
#     'future present': 0.009523809523809525}},
#   {'id': 'crime_news-985',
#    'sentence_tense_seq': {'present past': 0.24,
#     'past past': 0.6,
#     'past present': 0.12,
#     'present present': 0.04},
#    'full_tense_seq': {'present past': 0.1875,
#     'past past': 0.59375,
#     'past present': 0.15625,
#     'present present': 0.0625}},
#   {'id': 'crime_news-986',
#    'sentence_tense_seq': {'past past': 0.7073170731707317,
#     'past present': 0.14634146341463414,
#     'present present': 0.04878048780487805,
#     'present past': 0.0975609756097561},
#    'full_tense_seq': {'past past': 0.711864406779661,
#     'past present': 0.13559322033898305,
#     'present past': 0.11864406779661017,
#     'present present': 0.03389830508474576}},
#   {'id': 'crime_news-987',
#    'sentence_tense_seq': {'past past': 0.4393939393939394,
#     'past present': 0.21212121212121213,
#     'present past': 0.19696969696969696,
#     'present present': 0.12121212121212122,
#     'past future': 0.015151515151515152,
#     'future present': 0.015151515151515152},
#    'full_tense_seq': {'past past': 0.47126436781609193,
#     'past present': 0.20689655172413793,
#     'present past': 0.20689655172413793,
#     'present present': 0.09195402298850575,
#     'past future': 0.011494252873563218,
#     'future present': 0.011494252873563218}},
#   {'id': 'crime_news-988',
#    'sentence_tense_seq': {'present past': 0.23529411764705882,
#     'past past': 0.5588235294117647,
#     'past present': 0.17647058823529413,
#     'present present': 0.029411764705882353},
#    'full_tense_seq': {'present past': 0.21739130434782608,
#     'past past': 0.5217391304347826,
#     'past present': 0.1956521739130435,
#     'present present': 0.06521739130434782}},
#   {'id': 'crime_news-989',
#    'sentence_tense_seq': {'past past': 0.3,
#     'past present': 0.34,
#     'present past': 0.24,
#     'present present': 0.08,
#     'present future': 0.02,
#     'future present': 0.02},
#    'full_tense_seq': {'past past': 0.36363636363636365,
#     'past present': 0.2727272727272727,
#     'present past': 0.2727272727272727,
#     'present present': 0.06060606060606061,
#     'present future': 0.015151515151515152,
#     'future present': 0.015151515151515152}},
#   {'id': 'crime_news-990',
#    'sentence_tense_seq': {'present past': 0.234375,
#     'past past': 0.46875,
#     'past present': 0.203125,
#     'future past': 0.015625,
#     'present present': 0.078125},
#    'full_tense_seq': {'present past': 0.2087912087912088,
#     'past past': 0.45054945054945056,
#     'past present': 0.1978021978021978,
#     'past future': 0.01098901098901099,
#     'future past': 0.01098901098901099,
#     'present present': 0.12087912087912088}},
#   {'id': 'crime_news-991',
#    'sentence_tense_seq': {'past past': 0.6274509803921569,
#     'past present': 0.17647058823529413,
#     'present past': 0.0784313725490196,
#     'present present': 0.0784313725490196,
#     'present future': 0.0196078431372549,
#     'future past': 0.0196078431372549},
#    'full_tense_seq': {'past past': 0.6307692307692307,
#     'past present': 0.15384615384615385,
#     'present past': 0.12307692307692308,
#     'present present': 0.06153846153846154,
#     'present future': 0.015384615384615385,
#     'future past': 0.015384615384615385}},
#   {'id': 'crime_news-992',
#    'sentence_tense_seq': {'past past': 0.4375,
#     'past present': 0.1875,
#     'present present': 0.125,
#     'present past': 0.25},
#    'full_tense_seq': {'past past': 0.4186046511627907,
#     'past present': 0.23255813953488372,
#     'present present': 0.11627906976744186,
#     'present past': 0.23255813953488372}},
#   {'id': 'crime_news-993',
#    'sentence_tense_seq': {'past present': 0.34782608695652173,
#     'present past': 0.30434782608695654,
#     'past past': 0.30434782608695654,
#     'present present': 0.043478260869565216},
#    'full_tense_seq': {'past present': 0.3,
#     'present past': 0.3,
#     'past past': 0.36666666666666664,
#     'present present': 0.03333333333333333}},
#   {'id': 'crime_news-994',
#    'sentence_tense_seq': {'present past': 0.21212121212121213,
#     'past past': 0.24242424242424243,
#     'past present': 0.19696969696969696,
#     'present present': 0.24242424242424243,
#     'present future': 0.030303030303030304,
#     'future past': 0.015151515151515152,
#     'future present': 0.030303030303030304,
#     'past future': 0.030303030303030304},
#    'full_tense_seq': {'present past': 0.2159090909090909,
#     'past past': 0.26136363636363635,
#     'past present': 0.19318181818181818,
#     'present present': 0.20454545454545456,
#     'present future': 0.03409090909090909,
#     'future past': 0.011363636363636364,
#     'future present': 0.045454545454545456,
#     'past future': 0.03409090909090909}},
#   {'id': 'crime_news-995',
#    'sentence_tense_seq': {'past present': 0.2903225806451613,
#     'past past': 0.3870967741935484,
#     'present past': 0.1935483870967742,
#     'present present': 0.12903225806451613},
#    'full_tense_seq': {'past present': 0.2926829268292683,
#     'present past': 0.2926829268292683,
#     'past past': 0.3170731707317073,
#     'present present': 0.0975609756097561}},
#   {'id': 'crime_news-996',
#    'sentence_tense_seq': {'past present': 0.08108108108108109,
#     'present past': 0.1891891891891892,
#     'past past': 0.43243243243243246,
#     'present present': 0.1891891891891892,
#     'past future': 0.08108108108108109,
#     'future past': 0.02702702702702703},
#    'full_tense_seq': {'past present': 0.14,
#     'present past': 0.16,
#     'past past': 0.46,
#     'present present': 0.14,
#     'past future': 0.06,
#     'future present': 0.02,
#     'future past': 0.02}},
#   {'id': 'crime_news-997',
#    'sentence_tense_seq': {'present past': 0.15384615384615385,
#     'past past': 0.5,
#     'present future': 0.038461538461538464,
#     'future past': 0.038461538461538464,
#     'past present': 0.19230769230769232,
#     'present present': 0.07692307692307693},
#    'full_tense_seq': {'past present': 0.2571428571428571,
#     'present past': 0.22857142857142856,
#     'past past': 0.4,
#     'present future': 0.02857142857142857,
#     'future past': 0.02857142857142857,
#     'present present': 0.05714285714285714}},
#   {'id': 'crime_news-998',
#    'sentence_tense_seq': {'past past': 0.631578947368421,
#     'past future': 0.05263157894736842,
#     'future past': 0.10526315789473684,
#     'present past': 0.10526315789473684,
#     'past present': 0.05263157894736842,
#     'present present': 0.05263157894736842},
#    'full_tense_seq': {'past past': 0.6071428571428571,
#     'past future': 0.07142857142857142,
#     'future past': 0.07142857142857142,
#     'past present': 0.10714285714285714,
#     'present past': 0.07142857142857142,
#     'present present': 0.07142857142857142}},
#   {'id': 'crime_news-999',
#    'sentence_tense_seq': {'past present': 0.1694915254237288,
#     'present past': 0.1016949152542373,
#     'past future': 0.03389830508474576,
#     'future present': 0.01694915254237288,
#     'past past': 0.576271186440678,
#     'future past': 0.05084745762711865,
#     'present present': 0.05084745762711865},
#    'full_tense_seq': {'past present': 0.13924050632911392,
#     'present past': 0.13924050632911392,
#     'past future': 0.0379746835443038,
#     'future present': 0.012658227848101266,
#     'past past': 0.5822784810126582,
#     'future past': 0.0379746835443038,
#     'present present': 0.0379746835443038,
#     'present future': 0.012658227848101266}},
#   ...]}

# %% [markdown]
# ### JSON Output

# %%
def json_output(path, data):
    with open(path, 'w+') as of:
        json.dump(data, of)

# %%
for category in news_tense:
    json_output(f'output/{category}.json', news_tense[category])
json_output(f'output/all_data.json', news_tense)

# %% [markdown]
# ### CSV Output

# %%
import pandas as pd

# %%
news_tense_seq_flat = []

for category in news_tense:
    for article in news_tense[category]:
        rows = {}
        rows['category'] = category
        rows['id'] = article['id']
        for tense_seq in article['sentence_tense_seq']:
            rows[f's_{tense_seq}'] = article['sentence_tense_seq'][tense_seq]
        for tense_seq in article['full_tense_seq']:
            rows[f'f_{tense_seq}'] = article['full_tense_seq'][tense_seq]
        news_tense_seq_flat.append(rows)

# %%
df = pd.DataFrame(news_tense_seq_flat).fillna(0)
df.to_csv('output/all_data_flat.csv')

# %%
df
# Out:
#            category               id  s_present present  f_present present  \
# 0      weather_news   weather_news-0           1.000000           1.000000
# 1      weather_news   weather_news-1           0.062500           0.081633
# 2      weather_news   weather_news-2           0.000000           0.692308
# 3      weather_news   weather_news-3           0.594595           0.545455
# 4      weather_news   weather_news-4           0.461538           0.300000
# ...             ...              ...                ...                ...
# 14815    crime_news  crime_news-2029           0.142857           0.142857
# 14816    crime_news  crime_news-2030           0.218750           0.208333
# 14817    crime_news  crime_news-2031           0.057143           0.039216
# 14818    crime_news  crime_news-2032           0.068493           0.069307
# 14819    crime_news  crime_news-2033           0.080000           0.111111
#
#        s_present past  s_past past  s_past present  s_future present  \
# 0            0.000000     0.000000        0.000000          0.000000
# 1            0.250000     0.375000        0.218750          0.031250
# 2            0.000000     0.000000        0.000000          0.500000
# 3            0.108108     0.000000        0.081081          0.081081
# 4            0.115385     0.000000        0.000000          0.346154
# ...               ...          ...             ...               ...
# 14815        0.285714     0.285714        0.285714          0.000000
# 14816        0.250000     0.250000        0.218750          0.031250
# 14817        0.114286     0.600000        0.142857          0.028571
# 14818        0.191781     0.534247        0.164384          0.000000
# 14819        0.220000     0.320000        0.180000          0.040000
#
#        s_past future  s_future past  f_present past  f_past past  \
# 0           0.000000       0.000000        0.000000     0.000000
# 1           0.031250       0.031250        0.244898     0.367347
# 2           0.000000       0.000000        0.076923     0.000000
# 3           0.000000       0.000000        0.090909     0.000000
# 4           0.000000       0.000000        0.060000     0.000000
# ...              ...            ...             ...          ...
# 14815       0.000000       0.000000        0.285714     0.285714
# 14816       0.031250       0.000000        0.229167     0.312500
# 14817       0.028571       0.028571        0.156863     0.588235
# 14818       0.000000       0.027397        0.188119     0.504950
# 14819       0.080000       0.060000        0.194444     0.375000
#
#        f_past present  f_present future  f_future present  f_past future  \
# 0            0.000000          0.000000          0.000000       0.000000
# 1            0.224490          0.020408          0.020408       0.020408
# 2            0.076923          0.076923          0.076923       0.000000
# 3            0.064935          0.129870          0.142857       0.025974
# 4            0.040000          0.240000          0.260000       0.020000
# ...               ...               ...               ...            ...
# 14815        0.285714          0.000000          0.000000       0.000000
# 14816        0.208333          0.000000          0.020833       0.020833
# 14817        0.137255          0.000000          0.019608       0.039216
# 14818        0.198020          0.009901          0.000000       0.009901
# 14819        0.180556          0.013889          0.027778       0.055556
#
#        f_future past  s_present future  s_future future  f_future future
# 0           0.000000          0.000000         0.000000             0.00
# 1           0.020408          0.000000         0.000000             0.00
# 2           0.000000          0.500000         0.000000             0.00
# 3           0.000000          0.135135         0.000000             0.00
# 4           0.000000          0.000000         0.076923             0.08
# ...              ...               ...              ...              ...
# 14815       0.000000          0.000000         0.000000             0.00
# 14816       0.000000          0.000000         0.000000             0.00
# 14817       0.019608          0.000000         0.000000             0.00
# 14818       0.019802          0.013699         0.000000             0.00
# 14819       0.041667          0.020000         0.000000             0.00
#
# [14820 rows x 20 columns]
